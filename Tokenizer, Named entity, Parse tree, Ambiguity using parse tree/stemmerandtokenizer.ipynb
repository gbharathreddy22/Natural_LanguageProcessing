# %%
import nltk
from nltk.stem import PorterStemmer
a=PorterStemmer()
a.stem('Writing')
# Out:
# 'write'

# %%
a.stem('Playing')
# Out:
# 'play'

# %%
from nltk.tokenize import word_tokenize
word_tokenize('Nlp is a elective subject in sem 3')
# Out:
# ['Nlp', 'is', 'a', 'elective', 'subject', 'in', 'sem', '3']

# %%
word_tokenize('bharath is studying in sastra')
# Out:
# ['bharath', 'is', 'studying', 'in', 'sastra']

# %%
from nltk.tokenize import TreebankWordTokenizer
b=TreebankWordTokenizer()
b.tokenize('Nlp is a elective subject in sem 3')
# Out:
# ['Nlp', 'is', 'a', 'elective', 'subject', 'in', 'sem', '3']

# %%
import nltk
from nltk.tokenize import word_tokenize
word_tokenize('won’t')
# Out:
# ['won', '’', 't']

# %%
from nltk.tokenize import WordPunctTokenizer
tokenizer = WordPunctTokenizer()
tokenizer.tokenize(" I can't allow you to go home early")
# Out:
# ['I', 'can', "'", 't', 'allow', 'you', 'to', 'go', 'home', 'early']

# %%
import nltk
from nltk.tokenize import sent_tokenize
text = "Let us understand the difference between sentence & word tokenizer. It is going to be a simple example."
sent_tokenize(text)
# Out:
# ['Let us understand the difference between sentence & word tokenizer.',
#  'It is going to be a simple example.']

# %%
a=open("test.txt","r")
b=a.read()
print(b)
# Out:
# Hi Maâ€™am! Can you please help me with my bags?
# Good evening, Sir! May I know where I could find Mr (Name of the person)?
# Hello, I am here for my spa appointment. Can you tell me when I could go in?
# Good afternoon, Maâ€™am! I have missed my train. May I know when the next train to Bangalore is?
# Hi, good morning! There is a confusion with the namelists. Can you please help us out?
# Good morning/afternoon/evening! How are you today?
# Hey, how is everything going on? Hope you are doing well.
# Hello, there! I was wondering if I was in the right place. Is this â€¦.
# Hi! How was your weekend?
# Donâ€™t you think the weather is great today?

# %%
a=open("test.txt","r")
b=a.readline()
print(b)
# Out:
# Hi Maâ€™am! Can you please help me with my bags?

# %%
a=open("test.txt","r")
b=a.readlines()
print(b)
# Out:
# ['Hi Maâ€™am! Can you please help me with my bags?\n', 'Good evening, Sir! May I know where I could find Mr (Name of the person)?\n', 'Hello, I am here for my spa appointment. Can you tell me when I could go in?\n', 'Good afternoon, Maâ€™am! I have missed my train. May I know when the next train to Bangalore is?\n', 'Hi, good morning! There is a confusion with the namelists. Can you please help us out?\n', 'Good morning/afternoon/evening! How are you today?\n', 'Hey, how is everything going on? Hope you are doing well.\n', 'Hello, there! I was wondering if I was in the right place. Is this â€¦.\n', 'Hi! How was your weekend?\n', 'Donâ€™t you think the weather is great today?']

# %%
a=open("test.txt","r")
from nltk.tokenize import word_tokenize
b=a.readlines()
n=len(b)
for i in range(n):
    m=word_tokenize(b[i])
    print(m)
# Out:
# ['Hi', 'Maâ€™am', '!', 'Can', 'you', 'please', 'help', 'me', 'with', 'my', 'bags', '?']
# ['Good', 'evening', ',', 'Sir', '!', 'May', 'I', 'know', 'where', 'I', 'could', 'find', 'Mr', '(', 'Name', 'of', 'the', 'person', ')', '?']
# ['Hello', ',', 'I', 'am', 'here', 'for', 'my', 'spa', 'appointment', '.', 'Can', 'you', 'tell', 'me', 'when', 'I', 'could', 'go', 'in', '?']
# ['Good', 'afternoon', ',', 'Maâ€™am', '!', 'I', 'have', 'missed', 'my', 'train', '.', 'May', 'I', 'know', 'when', 'the', 'next', 'train', 'to', 'Bangalore', 'is', '?']
# ['Hi', ',', 'good', 'morning', '!', 'There', 'is', 'a', 'confusion', 'with', 'the', 'namelists', '.', 'Can', 'you', 'please', 'help', 'us', 'out', '?']
# ['Good', 'morning/afternoon/evening', '!', 'How', 'are', 'you', 'today', '?']
# ['Hey', ',', 'how', 'is', 'everything', 'going', 'on', '?', 'Hope', 'you', 'are', 'doing', 'well', '.']
# ...
